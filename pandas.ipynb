# %% [markdown]
# #### Import Pandas

# %%
import pandas as pd
import copy
dataFolder = "data/"
filename = {"file_1":"titanic.csv"}

# %% [markdown]
# ##### Read data

# %%
tmp_data = pd.read_csv(dataFolder+filename['file_1'])
data = copy.deepcopy(tmp_data)

# %% [markdown]
# ##### <font color="red">Row and Column</font>

# %%
print(data.shape)
print("Row : " + str(data.shape[0]) +"\t  Column : "+ str(data.shape[1]))
# Out:
# (891, 12)
# Row : 891	  Column : 12

# %%
data.columns.values[5]
data.keys()[5]
# Out:
# 'Age'

# %% [markdown]
# ##### Show first #no of rows

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# ##### Transpose data

# %%
data.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %% [markdown]
# ##### Basic Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
print(data.dtypes)
print("===========X===========")
print(data.dtypes['Name'])
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ===========X===========
# object

# %%
data.irow(2)
# Out:
# /home/arup/IDEs/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: irow(i) is deprecated. Please use .iloc[i]
#   if __name__ == '__main__':
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %% [markdown]
# ##### Iterate row

# %%
data.iloc[2]['Pclass']
# Out:
# 3

# %%
count = 0
for i, row in data.iterrows():
    print(str(i)+" = " +row['Name']+" = "+row['Sex'])
    count = count +1
    if count == 2:
        break
# Out:
# 0 = Braund, Mr. Owen Harris = male
# 1 = Cumings, Mrs. John Bradley (Florence Briggs Thayer) = female

# %% [markdown]
# ##### Iterate columns

# %%
for colname,coldata in data.items():
    print(colname)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %% [markdown]
# #### Describe data

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print("========Stat========")
print(data.min())
data.max()
data.std()
data.count()
data.sum()
data.median()
data.mean()
# Out:
# ========Stat========
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# temp           5.00
# dtype: float64
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# temp             5.0000
# dtype: float64

# %% [markdown]
# ##### Sort by column

# %%
data.sort_index(axis=1, ascending=False).head(5)
# Out:
#              Ticket  Survived  SibSp     Sex  Pclass  PassengerId  Parch  \
# 0         A/5 21171         0      1    male       3            1      0
# 1          PC 17599         1      1  female       1            2      0
# 2  STON/O2. 3101282         1      0  female       3            3      0
# 3            113803         1      1  female       1            4      0
# 4            373450         0      0    male       3            5      0
#
#                                                 Name     Fare Embarked Cabin  \
# 0                            Braund, Mr. Owen Harris   7.2500        S   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833        C   C85
# 2                             Heikkinen, Miss. Laina   7.9250        S   NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000        S  C123
# 4                           Allen, Mr. William Henry   8.0500        S   NaN
#
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %% [markdown]
# ##### Sort by values

# %%
data.sort_values(by='Fare').head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 597          598         0       3              Johnson, Mr. Alfred  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 277          278         0       2      Parkes, Mr. Francis "Frank"  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 271  25.0      0      0    LINE   0.0   NaN        S
# 597  49.0      0      0    LINE   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S
# 633   NaN      0      0  112052   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S

# %% [markdown]
# ### <font color="red">Selection</font>

# %%
data[['Pclass','Name']].head(2)
# Out:
#    Pclass                                               Name
# 0       3                            Braund, Mr. Owen Harris
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
data.iloc[:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data.iloc[890::]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
 data[0:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data[:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data[890:]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
data.loc[6]
# Out:
# PassengerId                          7
# Survived                             0
# Pclass                               1
# Name           McCarthy, Mr. Timothy J
# Sex                               male
# Age                                 54
# SibSp                                0
# Parch                                0
# Ticket                           17463
# Fare                           51.8625
# Cabin                              E46
# Embarked                             S
# Name: 6, dtype: object

# %%
data.loc[0:5,['PassengerId','Name']]
# Out:
#    PassengerId                                               Name
# 0            1                            Braund, Mr. Owen Harris
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3                             Heikkinen, Miss. Laina
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5                           Allen, Mr. William Henry
# 5            6                                   Moran, Mr. James

# %%
data.loc[5,['PassengerId','Name']]
# Out:
# PassengerId                   6
# Name           Moran, Mr. James
# Name: 5, dtype: object

# %%
data.loc[5,['PassengerId','Name']]['Name']
# Out:
# 'Moran, Mr. James'

# %%
data.at[5,'Name']
# Out:
# 'Moran, Mr. James'

# %%
data.iloc[3:5,2:5]
# Out:
#    Pclass                                          Name     Sex
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                      Allen, Mr. William Henry    male

# %%
data.iloc[1:3,:]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.iloc[1,3]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
data.iat[1,3]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
data.iloc[[1,2,4],[0,2,5]]
# Out:
#    PassengerId  Pclass   Age
# 1            2       1  38.0
# 2            3       3  26.0
# 4            5       3  35.0

# %% [markdown]
# ##### Boolean Indexing

# %%
data[data['Fare'] > 25]['Fare'].min()
data[data['Fare'] > 25]['Fare'].max()
data[data['Sex'] == 'female'].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
data[data['Pclass'].isin([1,2,5])]['Pclass'].head(3)#.unique()
# Out:
# 1    1
# 3    1
# 6    1
# Name: Pclass, dtype: int64

# %%
pd.isnull(data).head(4)
# Out:
#   PassengerId Survived Pclass   Name    Sex    Age  SibSp  Parch Ticket  \
# 0       False    False  False  False  False  False  False  False  False
# 1       False    False  False  False  False  False  False  False  False
# 2       False    False  False  False  False  False  False  False  False
# 3       False    False  False  False  False  False  False  False  False
#
#     Fare  Cabin Embarked
# 0  False   True    False
# 1  False  False    False
# 2  False   True    False
# 3  False  False    False

# %% [markdown]
# ##### Setting values by label

# %%
data.iat[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.iat[0,3] = 'Arup Nath Daw'
data.iat[0,3]
# Out:
# 'Arup Nath Daw'

# %%
data.at[0,'Name']
# Out:
# 'Arup Nath Daw'

# %%
import numpy as np
data.loc[:,'temp'] = np.array([5] * len(data))
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                      Arup Nath Daw    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  temp
# 0      0  A/5 21171   7.2500   NaN        S     5
# 1      0   PC 17599  71.2833   C85        C     5

# %%
#data[data > 200] = -data

# %% [markdown]
# ### Missing Data

# %%
data['Name'].value_counts().head(3)
# Out:
# Frost, Mr. Anthony Wood "Archie"    1
# Mionoff, Mr. Stoytcho               1
# Hansen, Mr. Henrik Juul             1
# Name: Name, dtype: int64

# %%
#To drop any rows that have missing data.
data.dropna(how='any')#.isnull()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
data.shape
# Out:
# (891, 13)

# %%
#Filling missing data
data.fillna(value=5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.isnull()
pd.isnull(data).head(2)
# Out:
#   PassengerId Survived Pclass   Name    Sex    Age  SibSp  Parch Ticket  \
# 0       False    False  False  False  False  False  False  False  False
# 1       False    False  False  False  False  False  False  False  False
#
#     Fare  Cabin Embarked   temp
# 0  False   True    False  False
# 1  False  False    False  False

# %%
#Operations in general exclude missing data.
data.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# temp             5.000000
# dtype: float64

# %%
data.mean(1).head(5)
# Out:
# 0     4.906250
# 1    14.910412
# 2     5.740625
# 3    12.512500
# 4     7.006250
# dtype: float64

# %%
data[data['Cabin'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...
